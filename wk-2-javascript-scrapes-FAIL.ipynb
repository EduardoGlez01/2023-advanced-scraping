# %% [markdown]
# ## Javascript Dynamic Scrapes
#
# Example sites:
# - <a href="https://a816-health.nyc.gov/ABCEatsRestaurants/#!/Search">Restaurant Inspections</a>
# - <a href="https://www1.nyc.gov/site/doh/health/health-topics/school-cafeteria-inspection-results.page">School cafeteria Inspections</a>
# - <a href="https://restructuring.primeclerk.com/pge/Home-ClaimInfo">PG&E bankruptcy claims</a>
# - <a href="https://eportal.miteco.gob.es/BoleHWeb/">Ministry for the Ecological Transition and the Demographic Challenge</a>
#
# Before we even scrape anything, let's find the sources of the sites above.

# %% [markdown]
# ## Scrape check cashing site
#
# We want all the check cashing locations in New York City.
#
# <a href="http://www.fscny.org/?controller=licensedlocations">Financial services check cashing</a>

# %%
## import libraries
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
from random import randint

# %%
## School Cafeteria inspection

# %%
import requests

headers = {
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Language': 'es-MX,es-419;q=0.9,es;q=0.8,en;q=0.7',
    'Connection': 'keep-alive',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.nyc.gov',
    'Referer': 'https://www.nyc.gov/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Mobile Safari/537.36',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
}

data = {
    'json': '{"AppID":"3236","FuncAlias":"schoolsmeta"}',
}

response = requests.post('https://a816-repportal.nyc.gov/ReportingPortal/Resource/Results', headers=headers, data=data)

# %%
response.json()
# Out:
# [{'I': '54722',
#   'N': '4- P.S. 041 FRANCIS WHITE, FIRST STEP NYC @ PS 41K',
#   'A': '411 THATFORD AVENUE, Brooklyn, NY 11212',
#   'Z': '11212',
#   'L': '08/04/2023'},
#  {'I': '53876',
#   'N': '47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECONDARY SCHOOL, P721M AT M047, THE 47 AMERICAN SIGN LANG',
#   'A': '223 EAST   23 STREET, New York, NY 10010',
#   'Z': '10010',
#   'L': '07/17/2023'},
#  {'I': '318998',
#   'N': 'A. FANTIS PAROCHIAL SCHOOL',
#   'A': '195 STATE STREET, Brooklyn, NY 11201',
#   'Z': '11201',
#   'L': '12/13/2022'},
#  {'I': '54130',
#   'N': 'A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL',
#   'A': '135 CONVENT AVENUE, New York, NY 10031',
#   'Z': '10031',
#   'L': '10/26/2023'},
#  {'I': '324475',
#   'N': 'ABRAHAM JOSHUA HESCHEL SCHOOL',
#   'A': '30 WEST END AVENUE, New York, NY 10023',
#   'Z': '10023',
#   'L': '05/15/2023'},
#  {'I': '54576',
#   'N': 'ABRAHAM LINCOLN HIGH SCHOOL',
#   'A': '2800 OCEAN PARKWAY, Brooklyn, NY 11235',
#   'Z': '11235',
# ...

# %%
df = pd.DataFrame(response.json())
df
# Out:
#            I                                                  N  \
# 0      54722  4- P.S. 041 FRANCIS WHITE, FIRST STEP NYC @ PS...
# 1      53876  47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...
# 2     318998                         A. FANTIS PAROCHIAL SCHOOL
# 3      54130              A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL
# 4     324475                      ABRAHAM JOSHUA HESCHEL SCHOOL
# ...      ...                                                ...
# 2188  377436                                Zeta Charter School
# 2189  379950                   Zeta Charter School -South Bronx
# 2190  358890                       ZETA CHARTER SCHOOL INWOOD I
# 2191  377434                               ZETA CHARTER SCHOOLS
# 2192   82731                       ZICHRON YEHUDA - BAIS SIMCHA
#
#                                              A      Z           L
# 0      411 THATFORD AVENUE, Brooklyn, NY 11212  11212  08/04/2023
# ...

# %% [markdown]
# ## Test on single page

# %%
##Multipage scrape
for page in range(1,4):

# %%
def strip_html(target):
    target = srt(target)
    soup = BeautifulSoup(target, "html.parser")
    return (soup.find("span", class_="table-content").get_text())

# %%
for target in target_cols:
    df[target].apply(lambda x: strip_html(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nf/t0yf6ph150x0p9rsc7rplh600000gn/T/ipykernel_4086/3557497404.py in <module>
# ----> 1 for target in target_cols:
#       2     df[target].apply(lambda x: strip_html(x))
#
# NameError: name 'target_cols' is not defined

# %%
import requests

url = "https://restructuring.ra.kroll.com/pge/Home-LoadClaimData"

payload = "json=%7B%22AppID%22%3A%223236%22%2C%22FuncAlias%22%3A%22schoolsmeta%22%7D"
headers = {
  'Accept': 'application/json, text/javascript, */*; q=0.01',
  'Accept-Language': 'es-MX,es-419;q=0.9,es;q=0.8,en;q=0.7',
  'Connection': 'keep-alive',
  'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
  'Origin': 'https://www.nyc.gov',
  'Referer': 'https://www.nyc.gov/',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Mobile Safari/537.36',
  'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
  'sec-ch-ua-mobile': '?1',
  'sec-ch-ua-platform': '"Android"',
  'Cookie': 'AWSALB=83gWA6wrbt/Zx7bMagCsswsriLP7OUBiwS1XTKyCT8KW6irHpyJCX0HYxxv1FhZJ+F3nweaDLcLLet4zKQB986cWIg+VtYeIvHQltSk13jbFBTER3W7aaa5nTIuQ; AWSALBCORS=83gWA6wrbt/Zx7bMagCsswsriLP7OUBiwS1XTKyCT8KW6irHpyJCX0HYxxv1FhZJ+F3nweaDLcLLet4zKQB986cWIg+VtYeIvHQltSk13jbFBTER3W7aaa5nTIuQ; AWSALBTG=Tfn3JBClWpuH8NoDKV32s8RTmOXkBSbe1jC4ncsI1z0f8hohDGvxxPjJq7LljIWUrn9xP6JSYcPGCmeb29+twDE9V9+yQ4P69QhovMvn62OykTLtiuWYHZ5NkQnPRIsiwWgMeNyIIRycpza6b8I50lTpSEekfmdCHJKvzZjLxh10; AWSALBTGCORS=Tfn3JBClWpuH8NoDKV32s8RTmOXkBSbe1jC4ncsI1z0f8hohDGvxxPjJq7LljIWUrn9xP6JSYcPGCmeb29+twDE9V9+yQ4P69QhovMvn62OykTLtiuWYHZ5NkQnPRIsiwWgMeNyIIRycpza6b8I50lTpSEekfmdCHJKvzZjLxh10; psi=555d5163-cf36-4877-a44c-a52542354d87'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)

# %%
response.json()

# %%
import requests

cookies = {
    '_ga': 'GA1.1.1194860065.1698156313',
    'LPVID': 'c4ODY4ZjNiMzUwZTljM2Vh',
    'aws-waf-token': '535ea384-6fe0-43aa-8a48-65e469e7a162:EQoAj2Rp0AwEAAAA:',
    'psi': '2f0a6a75-2197-4c4c-9a16-a22e2f1dbe49',
    'LPSID-16393053': 'x4uBm4P2TDu9JTgCPj0SiQ',
    '__cf_bm': 'iVWuoJkFb84NsPa1Umw71eDo3aBu45fHe5dmPFKyzzk-1699369643-0-AXAxCzdj69WpPdk2iWAGapKg9N9nmyjAxzDUnWOIsjGI8bGUqOZMEey2JW7Gg+O9EVhWIR6oWOnlK5Ob+VIb9qw=',
    'AWSALBTG': 'XopwhQBQHo9ZRF3fhvWkb996n+6UNNOHGGyd9ICzod54qmyPatgScBM/tGUJfQE1KE2vsMfSt4W6RMf1eQ+I+hfO2IwumjUw49NgMH9e7gWLZlJcHfmAtK+8Hfy9+4NleI5Mb/n+VuuWZwb7hB/1QXS11RnOqekMTFQkGpCUPk/X',
    'AWSALBTGCORS': 'XopwhQBQHo9ZRF3fhvWkb996n+6UNNOHGGyd9ICzod54qmyPatgScBM/tGUJfQE1KE2vsMfSt4W6RMf1eQ+I+hfO2IwumjUw49NgMH9e7gWLZlJcHfmAtK+8Hfy9+4NleI5Mb/n+VuuWZwb7hB/1QXS11RnOqekMTFQkGpCUPk/X',
    'AWSALB': 'wmZBbDBXXeEKT9DMzOC0UHs+v/Q/rYduepUTYv2xX3NtWWJxlat2Vq/4pB6RoEFurU8EeDqOVrG+9ZhgLHXNyyXQQC96UHV2Im2zdM6ckmEQyV5zuxWcOeheFGtY',
    'AWSALBCORS': 'wmZBbDBXXeEKT9DMzOC0UHs+v/Q/rYduepUTYv2xX3NtWWJxlat2Vq/4pB6RoEFurU8EeDqOVrG+9ZhgLHXNyyXQQC96UHV2Im2zdM6ckmEQyV5zuxWcOeheFGtY',
    '_ga_D5N0JEWGPF': 'GS1.1.1699369452.2.1.1699369797.0.0.0',
}

headers = {
    'authority': 'restructuring.ra.kroll.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'es-MX,es-419;q=0.9,es;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    # 'cookie': '_ga=GA1.1.1194860065.1698156313; LPVID=c4ODY4ZjNiMzUwZTljM2Vh; aws-waf-token=535ea384-6fe0-43aa-8a48-65e469e7a162:EQoAj2Rp0AwEAAAA:; psi=2f0a6a75-2197-4c4c-9a16-a22e2f1dbe49; LPSID-16393053=x4uBm4P2TDu9JTgCPj0SiQ; __cf_bm=iVWuoJkFb84NsPa1Umw71eDo3aBu45fHe5dmPFKyzzk-1699369643-0-AXAxCzdj69WpPdk2iWAGapKg9N9nmyjAxzDUnWOIsjGI8bGUqOZMEey2JW7Gg+O9EVhWIR6oWOnlK5Ob+VIb9qw=; AWSALBTG=XopwhQBQHo9ZRF3fhvWkb996n+6UNNOHGGyd9ICzod54qmyPatgScBM/tGUJfQE1KE2vsMfSt4W6RMf1eQ+I+hfO2IwumjUw49NgMH9e7gWLZlJcHfmAtK+8Hfy9+4NleI5Mb/n+VuuWZwb7hB/1QXS11RnOqekMTFQkGpCUPk/X; AWSALBTGCORS=XopwhQBQHo9ZRF3fhvWkb996n+6UNNOHGGyd9ICzod54qmyPatgScBM/tGUJfQE1KE2vsMfSt4W6RMf1eQ+I+hfO2IwumjUw49NgMH9e7gWLZlJcHfmAtK+8Hfy9+4NleI5Mb/n+VuuWZwb7hB/1QXS11RnOqekMTFQkGpCUPk/X; AWSALB=wmZBbDBXXeEKT9DMzOC0UHs+v/Q/rYduepUTYv2xX3NtWWJxlat2Vq/4pB6RoEFurU8EeDqOVrG+9ZhgLHXNyyXQQC96UHV2Im2zdM6ckmEQyV5zuxWcOeheFGtY; AWSALBCORS=wmZBbDBXXeEKT9DMzOC0UHs+v/Q/rYduepUTYv2xX3NtWWJxlat2Vq/4pB6RoEFurU8EeDqOVrG+9ZhgLHXNyyXQQC96UHV2Im2zdM6ckmEQyV5zuxWcOeheFGtY; _ga_D5N0JEWGPF=GS1.1.1699369452.2.1.1699369797.0.0.0',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Mobile Safari/537.36',
}

response = requests.get('https://restructuring.ra.kroll.com/pge/Home-ClaimInfo', cookies=cookies, headers=headers)

# %%
response.json()

# %%
response.json()

# %%
import requests

cookies = {
    '_ga': 'GA1.1.365766381.1697410558',
    '_ga_FSMM3JF7WP': 'GS1.1.1697479480.2.0.1697479480.0.0.0',
    '_ga_NFC36M4R02': 'GS1.1.1697914238.2.0.1697914238.0.0.0',
    'RT': '"z=1&dm=nyc.gov&si=hadyex12r46&ss=loofoemi&sl=0&tt=0"',
    '_ga_Z4PKRQHE6D': 'GS1.1.1699367743.3.1.1699369644.0.0.0',
    '_ga_V3XNM8HT8K': 'GS1.1.1699367743.3.1.1699369644.0.0.0',
    '_ga_BK7YKCZ5J8': 'GS1.1.1699370760.1.0.1699370760.0.0.0',
}

headers = {
    'Accept': 'application/json',
    'Accept-Language': 'es-MX,es-419;q=0.9,es;q=0.8,en;q=0.7',
    'Connection': 'keep-alive',
    # 'Cookie': '_ga=GA1.1.365766381.1697410558; _ga_FSMM3JF7WP=GS1.1.1697479480.2.0.1697479480.0.0.0; _ga_NFC36M4R02=GS1.1.1697914238.2.0.1697914238.0.0.0; RT="z=1&dm=nyc.gov&si=hadyex12r46&ss=loofoemi&sl=0&tt=0"; _ga_Z4PKRQHE6D=GS1.1.1699367743.3.1.1699369644.0.0.0; _ga_V3XNM8HT8K=GS1.1.1699367743.3.1.1699369644.0.0.0; _ga_BK7YKCZ5J8=GS1.1.1699370760.1.0.1699370760.0.0.0',
    'Referer': 'https://a816-health.nyc.gov/ABCEatsRestaurants/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Mobile Safari/537.36',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
}

response = requests.get(
    'https://a816-health.nyc.gov/ABCEatsRestaurants/App/GetEntitiesByBoro/Bronx',
    cookies=cookies,
    headers=headers,
)

# %%
response.json()

# %%
df_bronx = pd.DataFrame(response.json())
df_bronx

# %%
url_placeholder = "https://a816-health.nyc.gov/ABCEatsRestaurants/App/GetEntitiesByBoro/"
boros = ["Brooklyn", "Manhattan", "Bronx", "Queens"]

for boro in boros[0:4]:
    url = f"{url_placeholder}{boro}"
    print(url)
    response = requests.get(url)
    print(response.json())

# %%
boros[0]

# %%
cookies = {
    'JSESSIONID': '2ED19804EB0111992E0CEB90ABB0D2DF',
    '__utma': '8834785.550981488.1698155731.1698155731.1699371587.2',
    '__utmc': '8834785',
    '__utmz': '8834785.1699371587.2.2.utmcsr=localhost:8888|utmccn=(referral)|utmcmd=referral|utmcct=/',
    '__utmt_t0': '1',
    '__utmb': '8834785.20.10.1699371587',
}

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Language': 'es-MX,es-419;q=0.9,es;q=0.8,en;q=0.7',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Content-Type': 'application/x-www-form-urlencoded',
    # 'Cookie': 'JSESSIONID=2ED19804EB0111992E0CEB90ABB0D2DF; __utma=8834785.550981488.1698155731.1698155731.1699371587.2; __utmc=8834785; __utmz=8834785.1699371587.2.2.utmcsr=localhost:8888|utmccn=(referral)|utmcmd=referral|utmcct=/; __utmt_t0=1; __utmb=8834785.20.10.1699371587',
    'Origin': 'https://eportal.miteco.gob.es',
    'Referer': 'https://eportal.miteco.gob.es/BoleHWeb/bolehSRV',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Mobile Safari/537.36',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
}

data = {
    'xVal': '32',
    'fechaCalendario': '08/11/2023',
    'nombreReserva': '',
    'btnMod_Analisis_Reserva_1_3': 'btnMod_Analisis_Reserva_1_3',
}

response = requests.post('https://eportal.miteco.gob.es/BoleHWeb/bolehSRV', cookies=cookies, headers=headers, data=data)

# %% [raw]
# df = pd.DataFrame(response.json())
# df

# %%
## Founction to strip all the html using beautiful soup

def strip_html(target):
    target = srt(target)
    soup = BeautifulSoup(target, "html.parser")
    return (soup.find("span", class_="table-content").get_text())

# %%
target_cols = ["dates", "totals"]

# %%
for target in target_cols:
    df[target].apply(lambda x: strip_html(x))

# %%
df
##    print(target)
