# %% [markdown]
# # Scraping APIs
#
# A site with an API (Application Programming Interface) wants you to scrape it.
#
# Examples abound:
#
# * <a href="https://www.census.gov/data/developers/data-sets.html">U.S. Census APIs</a>
# * <a href="https://apps.fas.usda.gov/opendataweb/home">US Agriculture Commodities and Exports</a>
# * <a href="https://www.federalregister.gov/developers/documentation/api/v1">Federal Register</a>
# * <a href="https://developer.dol.gov/beginners-guide/">Labor Department</a>
# * <a href="https://www.eia.gov/">Labor Department</a>
#
# Government sites tend  ```CSVs``` for download but their APIs offer more detailed options for data. They are not trying to hide the data.
#
# Private sites might have APIs, but often charge heafty prices for access beyond a basic number of downloads.
#
# The toughest/hardest part of scraping an API is that they ***ALL HAVE DIFFERENT INSTRUCTIONS*** on how to tap their data.
#
# Today, we'll explore different APIs that each build a different skill:
#
# 1. Census health data – **building a simple API call.**
# 2. USDA commodities exports – **using an API key and targeting specific commodities over several years.**
# 3. Federal Register – **tapping search terms.**
# 4. Energy Information Administration – **dealing with pagination.**
#
# What they all have in common:
#
# 1. a base url
# 2. a query string
# 3. tied together with a query character ```?```
# 4. an API key.
#
# Combined together these are known as an ```API endpoint```.
#
# You make an ```API call``` (a request) using the ```API endpoint```.
#
#
# Today I've provided most the code, but you will have to build **your own API calls**.

# %%
## import libraries
import requests
import pandas as pd
from icecream import ic

# %% [markdown]
# ### 1. Census health data – **building a simple API call.**
#
# - <a href="https://www.census.gov/data/developers/data-sets/Health-Insurance-Statistics.html">Census health landing page</a>
# - List of <a href="https://api.census.gov/data/timeseries/healthins/sahie/variables.html">possible variables</a>
#
# We want to create a dataframe with the following info for every state in 2021:
#
# 1. Total number insured
# 2. Percent insured
# 3. Total number uninsured
# 4. Percent uninsured

# %% [markdown]
# ## the parts to build your API call.

# %%
## create a dictionary to know what codes mean
target_dict = {
    "NIC_PT": "total_insured",
    "PCTIC_PT": "pct_insure_est",
    "NUI_PT": "total_uninsured",
    "NUI_UB90": "pct_uninsured_ub90",
    "RACECAT": "race_category",
    "RACE_DESC": "race_description",
    "STABREV": "state"
}

# %%
##Keys() to get keys
list(target_dict.keys())
# Out:
# ['NIC_PT', 'PCTIC_PT', 'NUI_PT', 'NUI_UB90', 'RACECAT', 'RACE_DESC', 'STABREV']

# %%
## format into api query format
my_vars = ",".join(target_dict.keys())
my_vars
# Out:
# 'NIC_PT,PCTIC_PT,NUI_PT,NUI_UB90,RACECAT,RACE_DESC,STABREV'

# %%
## endpoint
base_url = "https://api.census.gov/data/timeseries/healthins/sahie?get="
target_year = "2021"

# %%
## create query string
query_str = f"{my_vars}&for=state:*&time={target_year}"
query_str
# Out:
# 'NIC_PT,PCTIC_PT,NUI_PT,NUI_UB90,RACECAT,RACE_DESC,STABREV&for=state:*&time=2021'

# %%
## create full API call
endpoint = base_url + query_str
endpoint
# Out:
# 'https://api.census.gov/data/timeseries/healthins/sahie?get=NIC_PT,PCTIC_PT,NUI_PT,NUI_UB90,RACECAT,RACE_DESC,STABREV&for=state:*&time=2021'

# %%
## get response
response = requests.get(endpoint)

# %%
## turn response into json
data = response.json()
data
# Out:
# [['NIC_PT',
#   'PCTIC_PT',
#   'NUI_PT',
#   'NUI_UB90',
#   'RACECAT',
#   'RACE_DESC',
#   'STABREV',
#   'time',
#   'state'],
#  ['3548525', '88.3', '469887', '484434', '0', 'All Races', 'AL', '2021', '01'],
#  ['2293718',
#   '90.0',
#   '254385',
#   '264792',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['921007',
#   '87.1',
#   '135939',
#   '143906',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['163769',
#   '73.3',
#   '59615',
#   '63181',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AL',
#   '2021',
#   '01'],
#  ['13274',
#   '83.7',
#   '2587',
#   '2863',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['57789',
#   '89.8',
#   '6551',
#   '7448',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['1784',
#   '84.9',
#   '317',
#   '375',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['97184',
#   '90.3',
#   '10493',
#   '11633',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AL',
#   '2021',
#   '01'],
#  ['530325', '86.8', '80538', '84822', '0', 'All Races', 'AK', '2021', '02'],
#  ['319149',
#   '90.1',
#   '35072',
#   '37911',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['16652',
#   '85.9',
#   '2726',
#   '3164',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['40054',
#   '79.6',
#   '10266',
#   '11361',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AK',
#   '2021',
#   '02'],
#  ['52439',
#   '74.8',
#   '17628',
#   '18767',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['34159',
#   '87.4',
#   '4903',
#   '5586',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['8269',
#   '83.6',
#   '1624',
#   '1863',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['59603',
#   '87.8',
#   '8319',
#   '9355',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AK',
#   '2021',
#   '02'],
#  ['5016330', '86.9', '758331', '777974', '0', 'All Races', 'AZ', '2021', '04'],
#  ['2540419',
#   '91.8',
#   '228172',
#   '238689',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['246304',
#   '88.7',
#   '31477',
#   '34647',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['1704504',
#   '80.5',
#   '411965',
#   '426325',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AZ',
#   '2021',
#   '04'],
#  ['131074',
#   '73.7',
#   '46821',
#   '49517',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['194847',
#   '91.5',
#   '18089',
#   '20052',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['9299',
#   '86.0',
#   '1509',
#   '1785',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['189883',
#   '90.3',
#   '20298',
#   '22317',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AZ',
#   '2021',
#   '04'],
#  ['2158741', '88.9', '268334', '278814', '0', 'All Races', 'AR', '2021', '05'],
#  ['1524234',
#   '91.1',
#   '149522',
#   '157398',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['330128',
#   '89.1',
#   '40192',
#   '43867',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['173378',
#   '73.9',
#   '61348',
#   '65285',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AR',
#   '2021',
#   '05'],
#  ['11671',
#   '83.0',
#   '2385',
#   '2649',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['40145',
#   '89.2',
#   '4873',
#   '5587',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['8509',
#   '80.2',
#   '2100',
#   '2383',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['70676',
#   '89.9',
#   '7914',
#   '8791',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AR',
#   '2021',
#   '05'],
#  ['30088120',
#   '91.9',
#   '2640001',
#   '2681093',
#   '0',
#   'All Races',
#   'CA',
#   '2021',
#   '06'],
#  ['9898657',
#   '95.6',
#   '454709',
#   '471119',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['1593081',
#   '93.5',
#   '110016',
#   '117488',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['12399750',
#   '87.4',
#   '1782382',
#   '1815955',
#   '3',
#   'Hispanic or Latino (any race)',
#   'CA',
#   '2021',
#   '06'],
#  ['80678',
#   '89.0',
#   '10006',
#   '10972',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['4572897',
#   '95.7',
#   '206391',
#   '216506',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['105713',
#   '91.7',
#   '9511',
#   '11235',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['1437344',
#   '95.5',
#   '66986',
#   '72007',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'CA',
#   '2021',
#   '06'],
#  ['4406138', '90.7', '452402', '467216', '0', 'All Races', 'CO', '2021', '08'],
#  ['2908433',
#   '93.6',
#   '200326',
#   '209842',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['175626',
#   '90.7',
#   '17950',
#   '20208',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['964105',
#   '82.3',
#   '206845',
#   '216423',
#   '3',
#   'Hispanic or Latino (any race)',
#   'CO',
#   '2021',
#   '08'],
#  ['18349',
#   '86.5',
#   '2872',
#   '3211',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['156586',
#   '93.1',
#   '11583',
#   '13056',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['6631',
#   '90.0',
#   '740',
#   '872',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['176408',
#   '93.6',
#   '12086',
#   '13472',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'CO',
#   '2021',
#   '08'],
#  ['2702690', '94.0', '172986', '182120', '0', 'All Races', 'CT', '2021', '09'],
#  ['1681248',
#   '96.3',
#   '65216',
#   '70219',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['288295',
#   '93.4',
#   '20377',
#   '22963',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['500962',
#   '86.8',
#   '76223',
#   '81777',
#   '3',
#   'Hispanic or Latino (any race)',
#   'CT',
#   '2021',
#   '09'],
#  ['4306',
#   '93.3',
#   '307',
#   '349',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['143851',
#   '95.3',
#   '7103',
#   '8164',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['959',
#   '93.9',
#   '62',
#   '77',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['83069',
#   '95.7',
#   '3698',
#   '4267',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'CT',
#   '2021',
#   '09'],
#  ['724470', '93.1', '53437', '57747', '0', 'All Races', 'DE', '2021', '10'],
#  ['415729',
#   '94.6',
#   '23781',
#   '26348',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['165228',
#   '93.6',
#   '11286',
#   '12887',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['78514',
#   '84.3',
#   '14608',
#   '16248',
#   '3',
#   'Hispanic or Latino (any race)',
#   'DE',
#   '2021',
#   '10'],
#  ['1408',
#   '91.0',
#   '140',
#   '161',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['32865',
#   '94.9',
#   '1754',
#   '2082',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['251',
#   '89.6',
#   '29',
#   '34',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['30475',
#   '94.3',
#   '1839',
#   '2133',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'DE',
#   '2021',
#   '10'],
#  ['528101', '96.3', '20443', '23332', '0', 'All Races', 'DC', '2021', '11'],
#  ['200355',
#   '97.8',
#   '4555',
#   '5383',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['218255',
#   '95.9',
#   '9390',
#   '11093',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['64529',
#   '92.7',
#   '5110',
#   '6046',
#   '3',
#   'Hispanic or Latino (any race)',
#   'DC',
#   '2021',
#   '11'],
#  ['680',
#   '94.4',
#   '40',
#   '46',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['23947',
#   '97.0',
#   '728',
#   '908',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['225',
#   '96.6',
#   '8',
#   '10',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['20110',
#   '97.0',
#   '612',
#   '746',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'DC',
#   '2021',
#   '11'],
#  ['14254979',
#   '84.9',
#   '2534999',
#   '2576054',
#   '0',
#   'All Races',
#   'FL',
#   '2021',
#   '12'],
#  ['7001974',
#   '87.5',
#   '999603',
#   '1024177',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['2293682',
#   '84.5',
#   '421800',
#   '438771',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['4032284',
#   '80.3',
#   '986549',
#   '1011444',
#   '3',
#   'Hispanic or Latino (any race)',
#   'FL',
#   '2021',
#   '12'],
#  ['24540',
#   '79.6',
#   '6274',
#   '6905',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['456376',
#   '89.2',
#   '55272',
#   '59721',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['9545',
#   '83.8',
#   '1839',
#   '2214',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['436578',
#   '87.3',
#   '63662',
#   '68153',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'FL',
#   '2021',
#   '12'],
#  ['7569926',
#   '85.2',
#   '1311686',
#   '1339829',
#   '0',
#   'All Races',
#   'GA',
#   '2021',
#   '13'],
#  ['3827292',
#   '88.2',
#   '509630',
#   '526239',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['2392964',
#   '85.2',
#   '415326',
#   '432174',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['718568',
#   '70.0',
#   '308410',
#   '319824',
#   '3',
#   'Hispanic or Latino (any race)',
#   'GA',
#   '2021',
#   '13'],
#  ['11442',
#   '80.3',
#   '2809',
#   '3115',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['366624',
#   '89.6',
#   '42596',
#   '46234',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['5221',
#   '82.1',
#   '1135',
#   '1342',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['247815',
#   '88.6',
#   '31780',
#   '34470',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'GA',
#   '2021',
#   '13'],
#  ['1159751', '95.6', '53490', '57667', '0', 'All Races', 'HI', '2021', '15'],
#  ['208257',
#   '95.7',
#   '9249',
#   '10549',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['21213',
#   '95.4',
#   '1028',
#   '1240',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['136165',
#   '92.9',
#   '10399',
#   '11727',
#   '3',
#   'Hispanic or Latino (any race)',
#   'HI',
#   '2021',
#   '15'],
#  ['1526',
#   '93.7',
#   '102',
#   '117',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['340585',
#   '96.3',
#   '12980',
#   '14653',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['97361',
#   '93.2',
#   '7112',
#   '8341',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['354644',
#   '96.6',
#   '12620',
#   '14253',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'HI',
#   '2021',
#   '15'],
#  ['1403972', '89.5', '163948', '172189', '0', 'All Races', 'ID', '2021', '16'],
#  ['1128221',
#   '91.6',
#   '103267',
#   '109799',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['10872',
#   '87.4',
#   '1565',
#   '1837',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['184280',
#   '79.1',
#   '48787',
#   '52492',
#   '3',
#   'Hispanic or Latino (any race)',
#   'ID',
#   '2021',
#   '16'],
#  ['9753',
#   '82.0',
#   '2147',
#   '2387',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['21430',
#   '90.1',
#   '2366',
#   '2752',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['2442',
#   '84.9',
#   '435',
#   '509',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['46974',
#   '89.7',
#   '5381',
#   '6108',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'ID',
#   '2021',
#   '16'],
#  ['9477028', '91.8', '845089', '865115', '0', 'All Races', 'IL', '2021', '17'],
#  ['5599607',
#   '94.7',
#   '314195',
#   '325650',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['1282220',
#   '91.2',
#   '124300',
#   '132388',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['1733966',
#   '83.2',
#   '348972',
#   '361454',
#   '3',
#   'Hispanic or Latino (any race)',
#   'IL',
#   '2021',
#   '17'],
#  ['9889',
#   '89.3',
#   '1184',
#   '1322',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['577415',
#   '93.5',
#   '40182',
#   '43638',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['2629',
#   '90.5',
#   '276',
#   '330',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['271302',
#   '94.4',
#   '15980',
#   '17652',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'IL',
#   '2021',
#   '17'],
#  ['5051991', '91.1', '494028', '509404', '0', 'All Races', 'IN', '2021', '18'],
#  ['3846012',
#   '92.1',
#   '329342',
#   '341775',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['486172',
#   '89.9',
#   '54376',
#   '59213',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['402927',
#   '83.3',
#   '80777',
#   '85882',
#   '3',
#   'Hispanic or Latino (any race)',
#   'IN',
#   '2021',
#   '18'],
#  ['7386',
#   '85.4',
#   '1267',
#   '1418',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['143268',
#   '91.5',
#   '13343',
#   '15033',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['2009',
#   '87.5',
#   '287',
#   '341',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['164217',
#   '91.8',
#   '14636',
#   '16220',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'IN',
#   '2021',
#   '18'],
#  ['2418667', '94.2', '148100', '154847', '0', 'All Races', 'IA', '2021', '19'],
#  ['1993828',
#   '95.2',
#   '99996',
#   '105322',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['102698',
#   '92.4',
#   '8401',
#   '9676',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['171504',
#   '85.5',
#   '29156',
#   '31671',
#   '3',
#   'Hispanic or Latino (any race)',
#   'IA',
#   '2021',
#   '19'],
#  ['5214',
#   '89.4',
#   '615',
#   '691',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['69553',
#   '92.9',
#   '5277',
#   '6124',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['4248',
#   '89.5',
#   '499',
#   '578',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['71622',
#   '94.5',
#   '4156',
#   '4740',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'IA',
#   '2021',
#   '19'],
#  ['2136120', '89.1', '260427', '269918', '0', 'All Races', 'KS', '2021', '20'],
#  ['1573464',
#   '91.6',
#   '144167',
#   '150922',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['114359',
#   '85.9',
#   '18741',
#   '20902',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['271305',
#   '78.4',
#   '74707',
#   '79133',
#   '3',
#   'Hispanic or Latino (any race)',
#   'KS',
#   '2021',
#   '20'],
#  ['11223',
#   '81.1',
#   '2623',
#   '2894',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['70882',
#   '90.5',
#   '7406',
#   '8413',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['2249',
#   '85.0',
#   '396',
#   '459',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['92638',
#   '88.2',
#   '12387',
#   '13696',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'KS',
#   '2021',
#   '20'],
#  ['3397006', '93.2', '246692', '257373', '0', 'All Races', 'KY', '2021', '21'],
#  ['2810916',
#   '94.1',
#   '176155',
#   '185148',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['272640',
#   '91.8',
#   '24482',
#   '27296',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['139490',
#   '80.5',
#   '33722',
#   '36487',
#   '3',
#   'Hispanic or Latino (any race)',
#   'KY',
#   '2021',
#   '21'],
#  ['4283',
#   '88.7',
#   '543',
#   '616',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['60425',
#   '93.0',
#   '4548',
#   '5246',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['2566',
#   '89.3',
#   '308',
#   '363',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['106686',
#   '93.9',
#   '6934',
#   '7824',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'KY',
#   '2021',
#   '21'],
#  ['3371196', '90.8', '339532', '352563', '0', 'All Races', 'LA', '2021', '22'],
#  ['1956008',
#   '92.6',
#   '156609',
#   '165266',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['1078618',
#   '91.0',
#   '106607',
#   '113961',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['170847',
#   '74.2',
#   '59253',
#   '63078',
#   '3',
#   'Hispanic or Latino (any race)',
#   'LA',
#   '2021',
#   '22'],
#  ['15130',
#   '83.8',
#   '2935',
#   '3245',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['63522',
#   '90.5',
#   '6634',
#   '7547',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['1228',
#   '86.9',
#   '185',
#   '221',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['85843',
#   '92.2',
#   '7309',
#   '8192',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'LA',
#   '2021',
#   '22'],
#  ['977273', '92.7', '77458', '82469', '0', 'All Races', 'ME', '2021', '23'],
#  ['891365',
#   '92.9',
#   '67840',
#   '72479',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['18598',
#   '91.2',
#   '1791',
#   '2129',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['20485',
#   '84.1',
#   '3860',
#   '4403',
#   '3',
#   'Hispanic or Latino (any race)',
#   'ME',
#   '2021',
#   '23'],
#  ['4538',
#   '88.8',
#   '573',
#   '651',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['13990',
#   '92.8',
#   '1090',
#   '1294',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['323',
#   '90.5',
#   '34',
#   '41',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['27974',
#   '92.5',
#   '2270',
#   '2622',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'ME',
#   '2021',
#   '23'],
#  ['4664762', '93.0', '349910', '362605', '0', 'All Races', 'MD', '2021', '24'],
#  ['2240688',
#   '96.0',
#   '92888',
#   '98783',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['1389705',
#   '93.5',
#   '96140',
#   '103082',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['504514',
#   '79.6',
#   '129598',
#   '136330',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MD',
#   '2021',
#   '24'],
#  ['7483',
#   '90.7',
#   '771',
#   '868',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['323314',
#   '94.4',
#   '19254',
#   '21339',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['2170',
#   '91.6',
#   '199',
#   '238',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['196888',
#   '94.7',
#   '11060',
#   '12350',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MD',
#   '2021',
#   '24'],
#  ['5420689', '97.1', '162727', '172020', '0', 'All Races', 'MA', '2021', '25'],
#  ['3645325',
#   '97.8',
#   '83829',
#   '90075',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['408167',
#   '96.0',
#   '16988',
#   '19380',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['766047',
#   '94.2',
#   '47076',
#   '51485',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MA',
#   '2021',
#   '25'],
#  ['6799',
#   '96.0',
#   '284',
#   '325',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['421881',
#   '97.5',
#   '10715',
#   '12253',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['2336',
#   '96.5',
#   '85',
#   '104',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['170134',
#   '97.8',
#   '3750',
#   '4357',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MA',
#   '2021',
#   '25'],
#  ['7585839', '94.0', '486048', '500323', '0', 'All Races', 'MI', '2021', '26'],
#  ['5511237',
#   '94.7',
#   '310872',
#   '321970',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['1019264',
#   '92.9',
#   '78320',
#   '84222',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['455469',
#   '88.5',
#   '59297',
#   '63373',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MI',
#   '2021',
#   '26'],
#  ['29514',
#   '87.3',
#   '4296',
#   '4743',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['275699',
#   '95.2',
#   '13764',
#   '15408',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['2018',
#   '91.4',
#   '191',
#   '231',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['292638',
#   '93.8',
#   '19308',
#   '21244',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MI',
#   '2021',
#   '26'],
#  ['4425088', '94.7', '247589', '256264', '0', 'All Races', 'MN', '2021', '27'],
#  ['3368712',
#   '95.8',
#   '147840',
#   '154121',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['332436',
#   '93.4',
#   '23374',
#   '26069',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['265823',
#   '85.2',
#   '46248',
#   '49722',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MN',
#   '2021',
#   '27'],
#  ['31608',
#   '85.7',
#   '5274',
#   '5813',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['253156',
#   '94.6',
#   '14402',
#   '16093',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['2579',
#   '92.1',
#   '221',
#   '261',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['170774',
#   '94.3',
#   '10230',
#   '11421',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MN',
#   '2021',
#   '27'],
#  ['2006272', '85.7', '335624', '348368', '0', 'All Races', 'MS', '2021', '28'],
#  ['1122985',
#   '87.5',
#   '160152',
#   '168679',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['748141',
#   '84.6',
#   '135690',
#   '143501',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['63694',
#   '70.2',
#   '27043',
#   '29116',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MS',
#   '2021',
#   '28'],
#  ['7207',
#   '76.6',
#   '2206',
#   '2443',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['22962',
#   '85.1',
#   '4024',
#   '4607',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['680',
#   '78.9',
#   '182',
#   '216',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['40603',
#   '86.5',
#   '6327',
#   '7097',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MS',
#   '2021',
#   '28'],
#  ['4403004', '88.6', '564179', '579723', '0', 'All Races', 'MO', '2021', '29'],
#  ['3428434',
#   '89.8',
#   '389830',
#   '402717',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['489170',
#   '86.2',
#   '78046',
#   '83634',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['203851',
#   '77.8',
#   '58264',
#   '61889',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MO',
#   '2021',
#   '29'],
#  ['12376',
#   '78.9',
#   '3302',
#   '3624',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['103480',
#   '90.3',
#   '11116',
#   '12414',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['6389',
#   '83.4',
#   '1271',
#   '1466',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['159304',
#   '87.7',
#   '22350',
#   '24224',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MO',
#   '2021',
#   '29'],
#  ['773064', '89.5', '90685', '95919', '0', 'All Races', 'MT', '2021', '30'],
#  ['660544',
#   '90.9',
#   '66058',
#   '70546',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['4374',
#   '86.0',
#   '715',
#   '846',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['35205',
#   '80.8',
#   '8387',
#   '9369',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MT',
#   '2021',
#   '30'],
#  ['32060',
#   '75.4',
#   '10464',
#   '11354',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['7940',
#   '88.8',
#   '998',
#   '1181',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['539',
#   '84.5',
#   '99',
#   '117',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['32402',
#   '89.1',
#   '3964',
#   '4513',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MT',
#   '2021',
#   '30'],
#  ['1470454', '91.5', '135758', '141927', '0', 'All Races', 'NE', '2021', '31'],
#  ['1121550',
#   '93.8',
#   '74289',
#   '78616',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['72859',
#   '89.9',
#   '8148',
#   '9295',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['175541',
#   '80.0',
#   '43857',
#   '47039',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NE',
#   '2021',
#   '31'],
#  ['8647',
#   '84.7',
#   '1558',
#   '1733',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['42399',
#   '91.8',
#   '3798',
#   '4386',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['973',
#   '88.4',
#   '128',
#   '156',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['48485',
#   '92.4',
#   '3980',
#   '4524',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NE',
#   '2021',
#   '31'],
#  ['2245764', '86.2', '358374', '370658', '0', 'All Races', 'NV', '2021', '32'],
#  ['995648',
#   '90.8',
#   '100989',
#   '107342',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['215839',
#   '87.9',
#   '29687',
#   '32717',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['679955',
#   '78.8',
#   '182966',
#   '191257',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NV',
#   '2021',
#   '32'],
#  ['12666',
#   '80.9',
#   '2986',
#   '3270',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['187680',
#   '89.2',
#   '22775',
#   '25101',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['14843',
#   '83.8',
#   '2877',
#   '3301',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['139133',
#   '89.6',
#   '16094',
#   '17854',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NV',
#   '2021',
#   '32'],
#  ['1026504', '93.7', '69294', '74359', '0', 'All Races', 'NH', '2021', '33'],
#  ['900220',
#   '94.2',
#   '55072',
#   '59456',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['16528',
#   '92.0',
#   '1437',
#   '1716',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['47581',
#   '85.2',
#   '8249',
#   '9380',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NH',
#   '2021',
#   '33'],
#  ['1407',
#   '90.2',
#   '153',
#   '176',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['33706',
#   '93.1',
#   '2500',
#   '2960',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['295',
#   '90.2',
#   '32',
#   '39',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['26767',
#   '93.5',
#   '1851',
#   '2147',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NH',
#   '2021',
#   '33'],
#  ['6916752', '91.7', '622957', '641059', '0', 'All Races', 'NJ', '2021', '34'],
#  ['3638761',
#   '95.6',
#   '168178',
#   '177045',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['878959',
#   '91.6',
#   '80508',
#   '86691',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['1459381',
#   '81.8',
#   '324230',
#   '336673',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NJ',
#   '2021',
#   '34'],
#  ['7344',
#   '91.1',
#   '716',
#   '805',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['744784',
#   '95.0',
#   '38858',
#   '42308',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['2402',
#   '91.8',
#   '214',
#   '256',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['185121',
#   '94.8',
#   '10253',
#   '11504',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NJ',
#   '2021',
#   '34'],
#  ['1441740', '87.4', '207637', '217559', '0', 'All Races', 'NM', '2021', '35'],
#  ['488791',
#   '93.3',
#   '35362',
#   '38668',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['28336',
#   '89.6',
#   '3275',
#   '3838',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['768417',
#   '84.8',
#   '138010',
#   '146216',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NM',
#   '2021',
#   '35'],
#  ['91276',
#   '78.7',
#   '24702',
#   '26380',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['25555',
#   '91.8',
#   '2297',
#   '2677',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['928',
#   '87.6',
#   '131',
#   '155',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['38437',
#   '90.9',
#   '3860',
#   '4436',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NM',
#   '2021',
#   '35'],
#  ['14935162',
#   '93.9',
#   '974408',
#   '998335',
#   '0',
#   'All Races',
#   'NY',
#   '2021',
#   '36'],
#  ['7977617',
#   '96.0',
#   '330086',
#   '342949',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['2088404',
#   '93.4',
#   '148380',
#   '157493',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['3000461',
#   '88.8',
#   '377637',
#   '392729',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NY',
#   '2021',
#   '36'],
#  ['31291',
#   '91.0',
#   '3094',
#   '3450',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['1370809',
#   '93.8',
#   '91181',
#   '97188',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['6808',
#   '92.3',
#   '569',
#   '669',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['459772',
#   '95.1',
#   '23461',
#   '25805',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NY',
#   '2021',
#   '36'],
#  ['7418267',
#   '87.5',
#   '1056777',
#   '1080064',
#   '0',
#   'All Races',
#   'NC',
#   '2021',
#   '37'],
#  ['4554632',
#   '90.6',
#   '473106',
#   '488770',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['1551071',
#   '87.4',
#   '223049',
#   '234173',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['718260',
#   '71.3',
#   '289577',
#   '299889',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NC',
#   '2021',
#   '37'],
#  ['55086',
#   '78.9',
#   '14754',
#   '15890',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['274809',
#   '91.7',
#   '24873',
#   '27324',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['5156',
#   '84.9',
#   '915',
#   '1082',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['259253',
#   '89.5',
#   '30503',
#   '33061',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NC',
#   '2021',
#   '37'],
#  ['570425', '90.8', '57728', '61442', '0', 'All Races', 'ND', '2021', '38'],
#  ['473921',
#   '92.4',
#   '39016',
#   '41977',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['19895',
#   '86.0',
#   '3249',
#   '3792',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['25954',
#   '79.8',
#   '6557',
#   '7398',
#   '3',
#   'Hispanic or Latino (any race)',
#   'ND',
#   '2021',
#   '38'],
#  ['20557',
#   '78.3',
#   '5699',
#   '6251',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['9954',
#   '90.1',
#   '1097',
#   '1295',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['422',
#   '85.1',
#   '74',
#   '85',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['19722',
#   '90.6',
#   '2036',
#   '2354',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'ND',
#   '2021',
#   '38'],
#  ['8721356', '92.2', '742266', '761759', '0', 'All Races', 'OH', '2021', '39'],
#  ['6659323',
#   '92.9',
#   '505357',
#   '521000',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['1088946',
#   '90.6',
#   '112354',
#   '119993',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['388594',
#   '83.7',
#   '75457',
#   '80370',
#   '3',
#   'Hispanic or Latino (any race)',
#   'OH',
#   '2021',
#   '39'],
#  ['10830',
#   '86.8',
#   '1646',
#   '1838',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['242225',
#   '91.8',
#   '21636',
#   '24027',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['3918',
#   '88.7',
#   '501',
#   '590',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['2702249', '83.1', '547685', '559561', '0', 'All Races', 'OK', '2021', '40'],
#  ['1715189',
#   '87.1',
#   '253789',
#   '262428',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['193873',
#   '83.4',
#   '38451',
#   '41375',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['150052',
#   '67.0',
#   '73991',
#   '76975',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['70220',
#   '86.6',
#   '10841',
#   '11955',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['5310',
#   '76.8',
#   '1607',
#   '1807',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['251213',
#   '83.1',
#   '51203',
#   '54244',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'OK',
#   '2021',
#   '40'],
#  ['3175341', '92.6', '252038', '262937', '0', 'All Races', 'OR', '2021', '41'],
#  ['2255995',
#   '94.0',
#   '144458',
#   '152617',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['23894',
#   '89.5',
#   '2812',
#   '3147',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['161478',
#   '94.7',
#   '9074',
#   '10316',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['13381',
#   '90.8',
#   '1356',
#   '1601',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['180022',
#   '94.1',
#   '11361',
#   '12775',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['9510210', '93.3', '681400', '699377', '0', 'All Races', 'PA', '2021', '42'],
#  ['6937761',
#   '94.3',
#   '422450',
#   '435765',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['1027525',
#   '92.8',
#   '79714',
#   '86068',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['851643',
#   '86.4',
#   '133800',
#   '141640',
#   '3',
#   'Hispanic or Latino (any race)',
#   'PA',
#   '2021',
#   '42'],
#  ['9367',
#   '90.1',
#   '1027',
#   '1149',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['392336',
#   '93.5',
#   '27480',
#   '30244',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['2926',
#   '91.6',
#   '267',
#   '316',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42'],
#  ['823704', '95.1', '42429', '46897', '0', 'All Races', 'RI', '2021', '44'],
#  ['554199',
#   '96.4',
#   '20522',
#   '23274',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['52516',
#   '95.2',
#   '2630',
#   '3166',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['154047',
#   '90.2',
#   '16727',
#   '18962',
#   '3',
#   'Hispanic or Latino (any race)',
#   'RI',
#   '2021',
#   '44'],
#  ['2503',
#   '94.0',
#   '159',
#   '184',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['30378',
#   '95.9',
#   '1302',
#   '1590',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['510',
#   '95.0',
#   '27',
#   '33',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['29551',
#   '96.5',
#   '1062',
#   '1273',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'RI',
#   '2021',
#   '44'],
#  ['3583330', '87.7', '500507', '516249', '0', 'All Races', 'SC', '2021', '45'],
#  ['2247878',
#   '89.9',
#   '253078',
#   '264003',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['218444',
#   '72.0',
#   '84783',
#   '89543',
#   '3',
#   'Hispanic or Latino (any race)',
#   'SC',
#   '2021',
#   '45'],
#  ['8853',
#   '79.6',
#   '2273',
#   '2507',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['71169',
#   '87.5',
#   '10199',
#   '11458',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['2089',
#   '82.6',
#   '439',
#   '518',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['110825',
#   '88.8',
#   '13964',
#   '15354',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['626412', '88.5', '81086', '85274', '0', 'All Races', 'SD', '2021', '46'],
#  ['512586',
#   '91.3',
#   '48748',
#   '52050',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['15285',
#   '83.5',
#   '3019',
#   '3504',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['30224',
#   '78.8',
#   '8117',
#   '9003',
#   '3',
#   'Hispanic or Latino (any race)',
#   'SD',
#   '2021',
#   '46'],
#  ['33200',
#   '67.3',
#   '16158',
#   '17252',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['11446',
#   '87.5',
#   '1630',
#   '1904',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['402',
#   '82.0',
#   '88',
#   '103',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['23269',
#   '87.5',
#   '3326',
#   '3786',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'SD',
#   '2021',
#   '46'],
#  ['4978730', '88.1', '670735', '688928', '0', 'All Races', 'TN', '2021', '47'],
#  ['3614551',
#   '90.0',
#   '402631',
#   '416764',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['811715',
#   '87.0',
#   '120878',
#   '128564',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['282712',
#   '70.9',
#   '116100',
#   '121751',
#   '3',
#   'Hispanic or Latino (any race)',
#   'TN',
#   '2021',
#   '47'],
#  ['9002',
#   '81.5',
#   '2047',
#   '2272',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['104137',
#   '89.7',
#   '11947',
#   '13420',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['2657',
#   '83.9',
#   '511',
#   '601',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['153956',
#   '90.3',
#   '16621',
#   '18254',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'TN',
#   '2021',
#   '47'],
#  ['19930607',
#   '79.7',
#   '5082397',
#   '5141926',
#   '0',
#   'All Races',
#   'TX',
#   '2021',
#   '48'],
#  ['8187256',
#   '87.8',
#   '1139837',
#   '1165988',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['2463370',
#   '82.9',
#   '506512',
#   '525045',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['7491457',
#   '70.0',
#   '3206096',
#   '3252005',
#   '3',
#   'Hispanic or Latino (any race)',
#   'TX',
#   '2021',
#   '48'],
#  ['44120',
#   '77.5',
#   '12827',
#   '13916',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['1192404',
#   '89.9',
#   '133689',
#   '141489',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['18266',
#   '80.8',
#   '4353',
#   '5135',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['533734',
#   '87.1',
#   '79083',
#   '83973',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'TX',
#   '2021',
#   '48'],
#  ['2622757', '89.9', '295109', '306158', '0', 'All Races', 'UT', '2021', '49'],
#  ['2046111',
#   '92.9',
#   '156459',
#   '164461',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['29736',
#   '86.8',
#   '4505',
#   '5193',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['349468',
#   '76.1',
#   '109545',
#   '115619',
#   '3',
#   'Hispanic or Latino (any race)',
#   'UT',
#   '2021',
#   '49'],
#  ['15988',
#   '80.6',
#   '3842',
#   '4248',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['65837',
#   '90.6',
#   '6867',
#   '7844',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['25609',
#   '85.9',
#   '4220',
#   '4963',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['90008',
#   '90.3',
#   '9671',
#   '10860',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'UT',
#   '2021',
#   '49'],
#  ['472219', '95.5', '22255', '24699', '0', 'All Races', 'VT', '2021', '50'],
#  ['428845',
#   '95.6',
#   '19559',
#   '21789',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['6713',
#   '94.6',
#   '386',
#   '479',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['11113',
#   '90.2',
#   '1205',
#   '1437',
#   '3',
#   'Hispanic or Latino (any race)',
#   'VT',
#   '2021',
#   '50'],
#  ['1011',
#   '93.4',
#   '72',
#   '85',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['10185',
#   '95.7',
#   '457',
#   '567',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['123',
#   '96.1',
#   '5',
#   '7',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['14229',
#   '96.1',
#   '571',
#   '692',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'VT',
#   '2021',
#   '50'],
#  ['6461548', '92.0', '559026', '575556', '0', 'All Races', 'VA', '2021', '51'],
#  ['3834139',
#   '94.4',
#   '226940',
#   '237223',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['1194156',
#   '92.2',
#   '100513',
#   '107453',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['643518',
#   '79.0',
#   '170682',
#   '178846',
#   '3',
#   'Hispanic or Latino (any race)',
#   'VA',
#   '2021',
#   '51'],
#  ['11250',
#   '88.8',
#   '1424',
#   '1597',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['475211',
#   '93.2',
#   '34529',
#   '37681',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['4409',
#   '89.8',
#   '503',
#   '609',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['298865',
#   '92.4',
#   '24435',
#   '26751',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'VA',
#   '2021',
#   '51'],
#  ['5944913', '92.4', '487958', '503031', '0', 'All Races', 'WA', '2021', '53'],
#  ['3771465',
#   '94.5',
#   '220580',
#   '230901',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['240385',
#   '91.4',
#   '22723',
#   '25318',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['821017',
#   '83.0',
#   '168430',
#   '176435',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WA',
#   '2021',
#   '53'],
#  ['48608',
#   '84.8',
#   '8744',
#   '9519',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['601403',
#   '94.4',
#   '35859',
#   '39229',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['42356',
#   '89.9',
#   '4758',
#   '5564',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['419679',
#   '94.0',
#   '26864',
#   '29465',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WA',
#   '2021',
#   '53'],
#  ['1277435', '92.3', '105912', '113011', '0', 'All Races', 'WV', '2021', '54'],
#  ['1158733',
#   '92.5',
#   '93387',
#   '100007',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['42252',
#   '91.6',
#   '3880',
#   '4551',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['24910',
#   '84.7',
#   '4490',
#   '5118',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WV',
#   '2021',
#   '54'],
#  ['1667',
#   '87.9',
#   '230',
#   '264',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['11430',
#   '92.2',
#   '967',
#   '1159',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['247',
#   '89.5',
#   '29',
#   '35',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['38196',
#   '92.9',
#   '2929',
#   '3386',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WV',
#   '2021',
#   '54'],
#  ['4422727', '93.5', '305258', '314853', '0', 'All Races', 'WI', '2021', '55'],
#  ['3480098',
#   '94.8',
#   '190641',
#   '197977',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['283440',
#   '91.8',
#   '25183',
#   '27836',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['346945',
#   '84.1',
#   '65422',
#   '69455',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WI',
#   '2021',
#   '55'],
#  ['27194',
#   '86.6',
#   '4201',
#   '4640',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['150742',
#   '93.1',
#   '11104',
#   '12536',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['1607',
#   '90.3',
#   '172',
#   '206',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['132701',
#   '94.0',
#   '8535',
#   '9510',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WI',
#   '2021',
#   '55'],
#  ['393704', '84.7', '71349', '75825', '0', 'All Races', 'WY', '2021', '56'],
#  ['329233',
#   '87.0',
#   '49396',
#   '53069',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['3750',
#   '80.5',
#   '911',
#   '1062',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['39116',
#   '71.4',
#   '15696',
#   '17220',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WY',
#   '2021',
#   '56'],
#  ['5559',
#   '70.8',
#   '2290',
#   '2505',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['4033',
#   '83.5',
#   '795',
#   '931',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['248',
#   '79.0',
#   '66',
#   '79',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['11765',
#   '84.3',
#   '2195',
#   '2499',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WY',
#   '2021',
#   '56'],
#  ['924072',
#   '87.2',
#   '135771',
#   '144051',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'SC',
#   '2021',
#   '45'],
#  ['327520',
#   '92.8',
#   '25315',
#   '27632',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'OH',
#   '2021',
#   '39'],
#  ['316392',
#   '72.9',
#   '117803',
#   '122637',
#   '3',
#   'Hispanic or Latino (any race)',
#   'OK',
#   '2021',
#   '40'],
#  ['63984',
#   '92.5',
#   '5210',
#   '6023',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'OR',
#   '2021',
#   '41'],
#  ['476587',
#   '86.0',
#   '77767',
#   '83228',
#   '3',
#   'Hispanic or Latino (any race)',
#   'OR',
#   '2021',
#   '41'],
#  ['288652',
#   '94.5',
#   '16662',
#   '18361',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'PA',
#   '2021',
#   '42']]

# %%
## create dataframe
df = pd.DataFrame(data[1:], columns =data[0])
df
# Out:
#       NIC_PT PCTIC_PT  NUI_PT NUI_UB90 RACECAT  \
# 0    3548525     88.3  469887   484434       0
# 1    2293718     90.0  254385   264792       1
# 2     921007     87.1  135939   143906       2
# 3     163769     73.3   59615    63181       3
# 4      13274     83.7    2587     2863       4
# ..       ...      ...     ...      ...     ...
# 403   327520     92.8   25315    27632       7
# 404   316392     72.9  117803   122637       3
# 405    63984     92.5    5210     6023       2
# 406   476587     86.0   77767    83228       3
# 407   288652     94.5   16662    18361       7
#
#                                              RACE_DESC STABREV  time state
# 0                                            All Races      AL  2021    01
# 1                  White alone, not Hispanic or Latino      AL  2021    01
# 2    Black or African American alone, not Hispanic ...      AL  2021    01
# 3                        Hispanic or Latino (any race)      AL  2021    01
# 4    American Indian and Alaska Native alone, not H...      AL  2021    01
# ..                                                 ...     ...   ...   ...
# 403          Two or More Races, not Hispanic or Latino      OH  2021    39
# 404                      Hispanic or Latino (any race)      OK  2021    40
# 405  Black or African American alone, not Hispanic ...      OR  2021    41
# 406                      Hispanic or Latino (any race)      OR  2021    41
# 407          Two or More Races, not Hispanic or Latino      PA  2021    42
#
# [408 rows x 9 columns]

# %%
## rename column headers with more meaning full headers
df.rename(columns = target_dict, inplace = True)
df
# Out:
#     total_insured pct_insure_est total_uninsured pct_uninsured_ub90  \
# 0         3548525           88.3          469887             484434
# 1         2293718           90.0          254385             264792
# 2          921007           87.1          135939             143906
# 3          163769           73.3           59615              63181
# 4           13274           83.7            2587               2863
# ..            ...            ...             ...                ...
# 403        327520           92.8           25315              27632
# 404        316392           72.9          117803             122637
# 405         63984           92.5            5210               6023
# 406        476587           86.0           77767              83228
# 407        288652           94.5           16662              18361
#
#     race_category                                   race_description state  \
# 0               0                                          All Races    AL
# 1               1                White alone, not Hispanic or Latino    AL
# 2               2  Black or African American alone, not Hispanic ...    AL
# 3               3                      Hispanic or Latino (any race)    AL
# 4               4  American Indian and Alaska Native alone, not H...    AL
# ..            ...                                                ...   ...
# 403             7          Two or More Races, not Hispanic or Latino    OH
# 404             3                      Hispanic or Latino (any race)    OK
# 405             2  Black or African American alone, not Hispanic ...    OR
# 406             3                      Hispanic or Latino (any race)    OR
# 407             7          Two or More Races, not Hispanic or Latino    PA
#
#      time state
# 0    2021    01
# 1    2021    01
# 2    2021    01
# 3    2021    01
# 4    2021    01
# ..    ...   ...
# 403  2021    39
# 404  2021    40
# 405  2021    41
# 406  2021    41
# 407  2021    42
#
# [408 rows x 9 columns]

# %% [markdown]
# ### 2. USDA commodities exports – **using an API key and targeting specific commodities over several years.**
#
# - <a href="https://apps.fas.usda.gov/opendataweb/home">USDA APIs endpoints</a>
# - Get an <a href="https://apps.fas.usda.gov/opendataweb/home">API key</a>
#
# We want to create a dataframe with exports between 2020-2022 to all countries for the following commodities:
#
# 1. All Wheat
# 2. Oats
# 3. Cuts of Beef
# 4. Cuts of Pork

# %%
## find the parts to build your API call

# %%
## get commodities list
com_url = "https://apps.fas.usda.gov/OpenData/api/esr/commodities"

# %%
## we create a headers with your API key- use your own
headers = {
    'API_KEY': 'ca089296-abd9-43af-ba6c-6bfbd4295c74'
}

# %%
## now let's put into get requests
## we check the response status code
response = requests.get(url = com_url, headers = headers)
response.status_code
all_commmodities = response.json()
all_commmodities
# Out:
# [{'commodityCode': 101, 'commodityName': 'Wheat - HRW', 'unitId': 1},
#  {'commodityCode': 102, 'commodityName': 'Wheat - SRW', 'unitId': 1},
#  {'commodityCode': 103, 'commodityName': 'Wheat - HRS', 'unitId': 1},
#  {'commodityCode': 104, 'commodityName': 'Wheat - White', 'unitId': 1},
#  {'commodityCode': 105, 'commodityName': 'Wheat - Durum', 'unitId': 1},
#  {'commodityCode': 106, 'commodityName': 'Wheat - Mixed', 'unitId': 1},
#  {'commodityCode': 107, 'commodityName': 'All Wheat', 'unitId': 1},
#  {'commodityCode': 201, 'commodityName': 'Wheat Products', 'unitId': 1},
#  {'commodityCode': 301, 'commodityName': 'Barley', 'unitId': 1},
#  {'commodityCode': 401, 'commodityName': 'Corn', 'unitId': 1},
#  {'commodityCode': 501, 'commodityName': 'Rye', 'unitId': 1},
#  {'commodityCode': 601, 'commodityName': 'Oats', 'unitId': 1},
#  {'commodityCode': 701, 'commodityName': 'Sorghum', 'unitId': 1},
#  {'commodityCode': 801, 'commodityName': 'Soybeans', 'unitId': 1},
#  {'commodityCode': 901, 'commodityName': 'Soybean cake & meal', 'unitId': 1},
#  {'commodityCode': 902, 'commodityName': 'Soybean Oil', 'unitId': 1},
#  {'commodityCode': 1001, 'commodityName': 'Flaxseed', 'unitId': 1},
#  {'commodityCode': 1101, 'commodityName': 'Linseed Oil', 'unitId': 1},
#  {'commodityCode': 1110, 'commodityName': 'Sunflowerseed Oil', 'unitId': 1},
#  {'commodityCode': 1201, 'commodityName': 'Cottonseed', 'unitId': 1},
#  {'commodityCode': 1202,
#   'commodityName': 'Cottonseed cake & meal',
#   'unitId': 1},
#  {'commodityCode': 1203, 'commodityName': 'Cottonseed Oil', 'unitId': 1},
#  {'commodityCode': 1301, 'commodityName': 'Cotton- Am Pima', 'unitId': 2},
#  {'commodityCode': 1401,
#   'commodityName': 'Cotton- Upland 1 1/16" & over',
#   'unitId': 2},
#  {'commodityCode': 1402,
#   'commodityName': 'Cotton- Upland 1"-1 1/16" & over',
#   'unitId': 2},
#  {'commodityCode': 1403,
#   'commodityName': 'Cotton- Upland under 1"',
#   'unitId': 2},
#  {'commodityCode': 1404, 'commodityName': 'All Upland Cotton', 'unitId': 2},
#  {'commodityCode': 1498, 'commodityName': 'Rice - LG Rough', 'unitId': 1},
#  {'commodityCode': 1499,
#   'commodityName': 'Rice- Med, Short,Other Rough',
#   'unitId': 1},
#  {'commodityCode': 1501, 'commodityName': 'Rice- LG Brown', 'unitId': 1},
#  {'commodityCode': 1502,
#   'commodityName': 'Rice- Med,Short, Other Brown',
#   'unitId': 1},
#  {'commodityCode': 1503,
#   'commodityName': 'Rice - Long Grain, Milled',
#   'unitId': 1},
#  {'commodityCode': 1504,
#   'commodityName': 'Rice- Med,Short,Other Milled',
#   'unitId': 1},
#  {'commodityCode': 1505, 'commodityName': 'All Rice', 'unitId': 1},
#  {'commodityCode': 1601,
#   'commodityName': 'Cattle Hides - Whole - Excluding Wet Blues',
#   'unitId': 3},
#  {'commodityCode': 1602,
#   'commodityName': 'Calf Skins - Whole - Excluding Wet Blues',
#   'unitId': 3},
#  {'commodityCode': 1603,
#   'commodityName': 'Kip Skins - Whole - Excluding Wet Blues',
#   'unitId': 3},
#  {'commodityCode': 1604,
#   'commodityName': 'Cattle Hides-Cut into Croupons, etc-excl Wet Blues',
#   'unitId': 4},
#  {'commodityCode': 1605,
#   'commodityName': 'Cattle Hides and Skins-other-excluding Wet Blues',
#   'unitId': 5},
#  {'commodityCode': 1606,
#   'commodityName': 'Cattle Wet Blues-Unsplit (Whole or Sided)',
#   'unitId': 4},
#  {'commodityCode': 1607,
#   'commodityName': 'Cattle Wet Blues-Grain Splits (Whole or Sided)',
#   'unitId': 4},
#  {'commodityCode': 1608,
#   'commodityName': 'Cattle Wet Blues-Splits-Excluding Grain Splits',
#   'unitId': 5},
#  {'commodityCode': 1701,
#   'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Beef',
#   'unitId': 1},
#  {'commodityCode': 1702,
#   'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Pork',
#   'unitId': 1}]

# %% [markdown]
# ### Get endpoint and test out on a single commodity

# %%
## your end point here
## Triying with all wheat
endpoint = "https://apps.fas.usda.gov/OpenData/api/esr/exports/commodityCode/107/allCountries/marketYear/2020"

# %%
## now let's put into get requests
## we check the response status code
response = requests.get(url = endpoint, headers = headers)
response.status_code
# Out:
# 200

# %%
## let's store our response into an object called datdf =

# %%
## convert that list of dicts into a dataframe called df
df = pd.DataFrame (response.json())
df
# Out:
#       commodityCode  countryCode  weeklyExports  accumulatedExports  \
# 0               107         1220            199                 199
# 1               107         2010          71970               71970
# 2               107         2050           3300                3300
# 3               107         2110           6600                6600
# 4               107         2150              0                   0
# ...             ...          ...            ...                 ...
# 3272            107         7740              0               19650
# 3273            107         7870           7250               11150
# 3274            107         7910          44000               80324
# 3275            107         7920           7150               13150
# 3276            107            2              0                   0
#
#       outstandingSales  grossNewSales  currentMYNetSales  \
# 0                18885          11268              10391
# 1               688745         365035              90031
# 2                15600           8800                300
# 3                23000          16551                600
# 4               112056           9278                  0
# ...                ...            ...                ...
# 3272                 0              0                  0
# 3273                 0             50               7250
# 3274                 0          44000              44000
# 3275                 0            650               7150
# 3276            239500              0             -25131
#
#       currentMYTotalCommitment  nextMYOutstandingSales  nextMYNetSales  \
# 0                        19084                       0               0
# 1                       760715                       0               0
# 2                        18900                       0               0
# 3                        29600                       0               0
# 4                       112056                       0               0
# ...                        ...                     ...             ...
# 3272                     19650                       0               0
# 3273                     11150                       0               0
# 3274                     80324                   13000          -40000
# 3275                     13150                       0               0
# 3276                    239500                  714470         -106371
#
#       unitId       weekEndingDate
# 0          1  2019-06-06T00:00:00
# 1          1  2019-06-06T00:00:00
# 2          1  2019-06-06T00:00:00
# 3          1  2019-06-06T00:00:00
# 4          1  2019-06-06T00:00:00
# ...      ...                  ...
# 3272       1  2020-06-04T00:00:00
# 3273       1  2020-06-04T00:00:00
# 3274       1  2020-06-04T00:00:00
# 3275       1  2020-06-04T00:00:00
# 3276       1  2020-06-04T00:00:00
#
# [3277 rows x 12 columns]

# %%
## Now iterate through all our target items

my_commodities = [{'commodityCode': 1702,
  'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Pork',
  'unitId': 1},
                 {'commodityCode': 1701,
  'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Beef',
  'unitId': 1},
                 {'commodityCode': 601, 'commodityName': 'Oats', 'unitId': 1},
                 {'commodityCode': 107, 'commodityName': 'All Wheat', 'unitId': 1}]
my_commodities
# Out:
# [{'commodityCode': 1702,
#   'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Pork',
#   'unitId': 1},
#  {'commodityCode': 1701,
#   'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Beef',
#   'unitId': 1},
#  {'commodityCode': 601, 'commodityName': 'Oats', 'unitId': 1},
#  {'commodityCode': 107, 'commodityName': 'All Wheat', 'unitId': 1}]

# %%
my_commodities[3].get('commodityCode')
# Out:
# 107

# %%
## endpoint templates
start_endpoint = "https://apps.fas.usda.gov/OpenData/api/esr/exports/commodityCode/"
end_endpoint = "/allCountries/marketYear/"

# %%
## iterate to get all the data
target_data = []
failed_endpoints = []
for commodity in my_commodities:
    target_code = commodity.get('commodityCode')
    ic(target_code)
    for year in range (2020, 2023):
        ic(year)
        try: 
            endpoint = f"{start_endpoint}{target_code}{end_endpoint}{year}"
            # Get response
            response = requests.get(url = endpoint, headers = headers)
            #Turn into dataframe
#            df = pd.DataFrame(response.json)
            target_data.append(pd.DataFrame(response.json()))
        except:
            print(f"Failed to retrieve data from{endpoint}... got status code{response.status_code}")
            failed_endpoints.append(endpoints)
print("done scraping API")
# Out:
# ic| target_code: 1702
# ic| year: 2020
# ic| year: 2021
# ic| year: 2022
# ic| target_code: 1701
# ic| year: 2020
# ic| year: 2021
# ic| year: 2022
# ic| target_code: 601
# ic| year: 2020
# ic| year: 2021
# ic| year: 2022
# ic| target_code: 107
# ic| year: 2020
# ic| year: 2021
# ic| year: 2022
# done scraping API

# %%
## call list
len(target_data)
# Out:
# 12

# %%
## concat into single df
df = pd.concat(target_data).reset_index(drop = True)
df
# Out:
#        commodityCode  countryCode  weeklyExports  accumulatedExports  \
# 0               1702         1220            166                 166
# 1               1702         2010            529                 529
# 2               1702         2050              0                   0
# 3               1702         2110              0                   0
# 4               1702         2150             53                  53
# ...              ...          ...            ...                 ...
# 30828            107         7520              0                2250
# 30829            107         7530          12100             1677039
# 30830            107         7870              0               13200
# 30831            107         7910              0               19296
# 30832            107            2              0               16500
#
#        outstandingSales  grossNewSales  currentMYNetSales  \
# 0                 12040           9666                624
# 1                 68683          53309               7125
# 2                  1370           1144                 67
# 3                   292            274                 94
# 4                   907            289                  3
# ...                 ...            ...                ...
# 30828                 0              0                  0
# 30829             96075              0                  0
# 30830                 0              0                  0
# 30831                 0              0                  0
# 30832            107801              0                  0
#
#        currentMYTotalCommitment  nextMYOutstandingSales  nextMYNetSales  \
# 0                         12206                       0               0
# 1                         69212                       0               0
# 2                          1370                       0               0
# 3                           292                       0               0
# 4                           960                       0               0
# ...                         ...                     ...             ...
# 30828                      2250                       0               0
# 30829                   1773114                  286175            1100
# 30830                     13200                       0               0
# 30831                     19296                       0               0
# 30832                    124301                  618333          117600
#
#        unitId       weekEndingDate
# 0           1  2020-01-02T00:00:00
# 1           1  2020-01-02T00:00:00
# 2           1  2020-01-02T00:00:00
# 3           1  2020-01-02T00:00:00
# 4           1  2020-01-02T00:00:00
# ...       ...                  ...
# 30828       1  2022-06-02T00:00:00
# 30829       1  2022-06-02T00:00:00
# 30830       1  2022-06-02T00:00:00
# 30831       1  2022-06-02T00:00:00
# 30832       1  2022-06-02T00:00:00
#
# [30833 rows x 12 columns]

# %%
## call df
df
# Out:
#        commodityCode  countryCode  weeklyExports  accumulatedExports  \
# 0               1702         1220            166                 166
# 1               1702         2010            529                 529
# 2               1702         2050              0                   0
# 3               1702         2110              0                   0
# 4               1702         2150             53                  53
# ...              ...          ...            ...                 ...
# 30828            107         7520              0                2250
# 30829            107         7530          12100             1677039
# 30830            107         7870              0               13200
# 30831            107         7910              0               19296
# 30832            107            2              0               16500
#
#        outstandingSales  grossNewSales  currentMYNetSales  \
# 0                 12040           9666                624
# 1                 68683          53309               7125
# 2                  1370           1144                 67
# 3                   292            274                 94
# 4                   907            289                  3
# ...                 ...            ...                ...
# 30828                 0              0                  0
# 30829             96075              0                  0
# 30830                 0              0                  0
# 30831                 0              0                  0
# 30832            107801              0                  0
#
#        currentMYTotalCommitment  nextMYOutstandingSales  nextMYNetSales  \
# 0                         12206                       0               0
# 1                         69212                       0               0
# 2                          1370                       0               0
# 3                           292                       0               0
# 4                           960                       0               0
# ...                         ...                     ...             ...
# 30828                      2250                       0               0
# 30829                   1773114                  286175            1100
# 30830                     13200                       0               0
# 30831                     19296                       0               0
# 30832                    124301                  618333          117600
#
#        unitId       weekEndingDate
# 0           1  2020-01-02T00:00:00
# 1           1  2020-01-02T00:00:00
# 2           1  2020-01-02T00:00:00
# 3           1  2020-01-02T00:00:00
# 4           1  2020-01-02T00:00:00
# ...       ...                  ...
# 30828       1  2022-06-02T00:00:00
# 30829       1  2022-06-02T00:00:00
# 30830       1  2022-06-02T00:00:00
# 30831       1  2022-06-02T00:00:00
# 30832       1  2022-06-02T00:00:00
#
# [30833 rows x 12 columns]

# %%
## confirm we have all our target commodities
list(df("commodityCode").unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nf/t0yf6ph150x0p9rsc7rplh600000gn/T/ipykernel_19881/1603010373.py in <module>
#       1 ## confirm we have all our target commodities
# ----> 2 list(df("commodityCode").unique())
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ### 3. Federal Register – **tapping search terms.**
#
# We have decades of <a href="https://docs.google.com/spreadsheets/d/130WeumbMZjcoRP4D-1uJ7bM0aKBZzt4N/edit?usp=sharing&ouid=112307892189798608417&rtpof=true&sd=true">SBA Excel files</a> that detail loans given to small businesses to recover after climate disasters. The only information we have about the type of disasters are codes in one of the columns that look like:
#
# - CA-00279
# - IL-00051
# - NC-00099
#
# The <a href="https://www.federalregister.gov/">Federal Register</a> allows us to search for what these codes stand for. But we can't search for nearly a thousand such disaster codes. When we try to scrape the site, it warns us to use the API instead.
#
# Federal Register <a href="https://www.federalregister.gov/developers/documentation/api/v1#/Federal%20Register%20Documents/get_documents__format_">API documentation</a>

# %%
## find the endpoint
endpoint = ""

# %% [markdown]
# ## NOTAS:
# base URL:
# https://www.federalregister.gov/api/v1/
#
#
# documents/%7Bdocument_numbers%7D.%7Bformat%7D

# %% [markdown]
# #### Test on single endpoint after figuring out how to build API call

# %%
## endpoint

# %%
## get data

# %%
## type

# %%
## targeting incidents

# %% [markdown]
# ### Iterate through entire list of codes

# %%
## Normally will take from df as a list
## build disaster code list
disaster_codes = ["CA-00279","IL-00051", "NC-00099" ]

# %%
## provide base url

# %%
## iterate through all endpoints

# %%
## call list

# %% [markdown]
# ### 4. Energy Information Administration – **dealing with pagination.**
#
# From the <a href="https://www.eia.gov/">Energy Information Administration</a>, we want to compile energy generation by type of fuel and region for about 5 days.
#
# We will encounter a limit on the number of items per API call.
#
# Find our API endpoint first.

# %%
## your target endpoint

# %%
## get response

# %%
## import ceiling division from math

# %%
## paginate our API calls

# %%
## for loop with pagination

# %%
## call all data

# %%
## length

# %%
## use itertools to flatten list with nested lists

# %%
## flatten nested lists

# %%
## convert to df

# %%
fips_codes = {
    'Alabama': '01',
    'Alaska': '02',
    'Arizona': '04',
    'Arkansas': '05',
    'California': '06',
    'Colorado': '08',
    'Connecticut': '09',
    'Delaware': '10',
    'Florida': '12',
    'Georgia': '13',
    'Hawaii': '15',
    'Idaho': '16',
    'Illinois': '17',
    'Indiana': '18',
    'Iowa': '19',
    'Kansas': '20',
    'Kentucky': '21',
    'Louisiana': '22',
    'Maine': '23',
    'Maryland': '24',
    'Massachusetts': '25',
    'Michigan': '26',
    'Minnesota': '27',
    'Mississippi': '28',
    'Missouri': '29',
    'Montana': '30',
    'Nebraska': '31',
    'Nevada': '32',
    'New Hampshire': '33',
    'New Jersey': '34',
    'New Mexico': '35',
    'New York': '36',
    'North Carolina': '37',
    'North Dakota': '38',
    'Ohio': '39',
    'Oklahoma': '40',
    'Oregon': '41',
    'Pennsylvania': '42',
    'Rhode Island': '44',
    'South Carolina': '45',
    'South Dakota': '46',
    'Tennessee': '47',
    'Texas': '48',
    'Utah': '49',
    'Vermont': '50',
    'Virginia': '51',
    'Washington': '53',
    'West Virginia': '54',
    'Wisconsin': '55',
    'Wyoming': '56',
    'District of Columbia': '11',
    'Puerto Rico': '72'
}
